# %% [markdown]
# Getting set up

# %%
#if you have not installed folium yet:
#!pip install folium

import folium
import pandas as pd

# %%
utah_df = pd.read_csv('1871-utah-postmaster-salaries.csv')
print(utah_df.sample(5))
utah_df.dtypes
# Out:
#         PO_Name      County State  PM_Salary   Latitude   Longitude
# 68        Manti     Sanpete    UT        100  39.267462 -111.636585
# 97   Providence       Cache    UT         38  41.708265 -111.817998
# 131  Wellsville       Cache    UT        360  41.639099 -111.933279
# 39      Grafton  Washington    UT         12  37.167205 -113.079943
# 61     Laketown        Utah    UT         12        NaN         NaN
# PO_Name       object
# County        object
# State         object
# PM_Salary      int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %% [markdown]
# Base Map

# %%
utah_map_empty = folium.Map(location=[40, -111], zoom_start=6)
utah_map_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0910a84cfa6f5f8f25922a81ee876a88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0910a84cfa6f5f8f25922a81ee876a88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0910a84cfa6f5f8f25922a81ee876a88 = L.map(
#                 &quot;map_0910a84cfa6f5f8f25922a81ee876a88&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cca5956d0814a6dce3cdc7eb6f466adc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cca5956d0814a6dce3cdc7eb6f466adc.addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Creating Reusable base map

# %%
def create_empty_map():
    return folium.Map(location=[40, -111], zoom_start=6)

utah_map = create_empty_map()
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5727cfe9e116ec415f031ed9a46a0d0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5727cfe9e116ec415f031ed9a46a0d0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5727cfe9e116ec415f031ed9a46a0d0a = L.map(
#                 &quot;map_5727cfe9e116ec415f031ed9a46a0d0a&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fa55feaa3e8dda63ec824299494120b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fa55feaa3e8dda63ec824299494120b.addTo(map_5727cfe9e116ec415f031ed9a46a0d0a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Check missing data

# %%
# Check for columns with missing values
missing_values = utah_df.isna().sum()
print(missing_values)
# Out:
# PO_Name      0
# County       0
# State        0
# PM_Salary    0
# Latitude     4
# Longitude    4
# dtype: int64

# %%
# Filter out post offices that are missing a latitude value (ie. we don't have any location information about it)
utah_df_locations = utah_df[utah_df['Latitude'].notna()]
print(len(utah_df))
print(len(utah_df_locations))
# Out:
# 136
# 132

# %% [markdown]
# Adding points on map

# %%
folium.Marker(location=[38.41, -112.339], popup="Adamsville Post Office").add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5727cfe9e116ec415f031ed9a46a0d0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5727cfe9e116ec415f031ed9a46a0d0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5727cfe9e116ec415f031ed9a46a0d0a = L.map(
#                 &quot;map_5727cfe9e116ec415f031ed9a46a0d0a&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fa55feaa3e8dda63ec824299494120b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fa55feaa3e8dda63ec824299494120b.addTo(map_5727cfe9e116ec415f031ed9a46a0d0a);
#
#
#             tile_layer_2fa55feaa3e8dda63ec824299494120b.addTo(map_5727cfe9e116ec415f031ed9a46a0d0a);
#
#
#             var marker_05b6266c91c17b0595230f937216adf2 = L.marker(
#                 [38.41, -112.339],
#                 {
# }
#             ).addTo(map_5727cfe9e116ec415f031ed9a46a0d0a);
#
#
#         var popup_9f3431b6f09a556d43baf02156debc1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0514a56ba8b6c55fd79392d95a3583bd = $(`&lt;div id=&quot;html_0514a56ba8b6c55fd79392d95a3583bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville Post Office&lt;/div&gt;`)[0];
#                 popup_9f3431b6f09a556d43baf02156debc1e.setContent(html_0514a56ba8b6c55fd79392d95a3583bd);
#
#
#
#         marker_05b6266c91c17b0595230f937216adf2.bindPopup(popup_9f3431b6f09a556d43baf02156debc1e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Defining a marker

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['PO_Name']).add_to(map_name)

# %%
#create a base empty map
utah_map = create_empty_map()

#generate a random row of data
sample_row = utah_df_locations.sample(1)

#use our function on the random row
create_map_markers(sample_row, utah_map)

#display the map
utah_map
# Out:
# C:\Users\rlove\anaconda3\Lib\site-packages\folium\utilities.py:101: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# C:\Users\rlove\anaconda3\Lib\site-packages\folium\utilities.py:107: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# C:\Users\rlove\anaconda3\Lib\site-packages\folium\utilities.py:109: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_278906ba00d0aba99034c74c5c05d252 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_278906ba00d0aba99034c74c5c05d252&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_278906ba00d0aba99034c74c5c05d252 = L.map(
#                 &quot;map_278906ba00d0aba99034c74c5c05d252&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27a35d9f06cbf2c9d003c1539f774476 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27a35d9f06cbf2c9d003c1539f774476.addTo(map_278906ba00d0aba99034c74c5c05d252);
#
#
#             var marker_85a4a0079ffc46fdd1dab9d7226462ed = L.marker(
#                 [39.9099498, -112.1299456],
#                 {
# }
#             ).addTo(map_278906ba00d0aba99034c74c5c05d252);
#
#
#         var popup_36752b465a76bb198f9959db098f5ce7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbbb280a693ffa9843b0c3064d619224 = $(`&lt;div id=&quot;html_bbbb280a693ffa9843b0c3064d619224&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;109    Silver City Name: PO_Name, dtype: object&lt;/div&gt;`)[0];
#                 popup_36752b465a76bb198f9959db098f5ce7.setContent(html_bbbb280a693ffa9843b0c3064d619224);
#
#
#
#         marker_85a4a0079ffc46fdd1dab9d7226462ed.bindPopup(popup_36752b465a76bb198f9959db098f5ce7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adding markers for a For Loop

# %%
# Method 1: Using a for loop to iterate through our dataframe and add markers sequentially
# initialize an empty map
utah_map = create_empty_map()

# iterrows() allows you to loop through a dataframe row by row and return the index position + the row
for index, row in utah_df_locations.iterrows():
    print(f"Name of post office:", row[0])

#now let's iterate through and call our function for each row
for index, row in utah_df_locations.iterrows():
    create_map_markers(row, utah_map)

utah_map
# Out:
# Name of post office: Adamsville
# Name of post office: Alma
# Name of post office: Alpine City
# Name of post office: American Fork
# Name of post office: Bellevue
# Name of post office: Bingham Canyon
# Name of post office: Brigham City
# Name of post office: Bullion
# Name of post office: Cedar City
# Name of post office: Cedar Valley
# Name of post office: Centerville
# Name of post office: Central City
# Name of post office: Chicken Creek
# Name of post office: Clarkston
# Name of post office: Clifton
# Name of post office: Clover Valley
# Name of post office: Coalville
# Name of post office: Corinne
# Name of post office: Cove Creek
# Name of post office: Croydon
# Name of post office: Deseret
# Name of post office: Diamond
# Name of post office: Draper
# Name of post office: Duncans Retreat
quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d02224cc0d1ddaaa273593e408ffdc2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d02224cc0d1ddaaa273593e408ffdc2b.addTo(map_bf911903f77e6a6a86aecbfeda70cfe9);
#
#
#             var marker_982c13ad49240377db2a03a205d7eae2 = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_bf911903f77e6a6a86aecbfeda70cfe9);
#
#
#         var popup_3b06c0a1abd31f6692e9ded61629b92f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a1480eab90ad515d5f97d447bb9ec93 = $(`&lt;div id=&quot;html_8a1480eab90ad515d5f97d447bb9ec93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_3b06c0a1abd31f6692e9ded61629b92f.setContent(html_8a1480eab90ad515d5f97d447bb9ec93);
#
#
#
#         marker_982c13ad49240377db2a03a205d7eae2.bindPopup(popup_3b06c0a1abd31f6692e9ded61629b92f)
#         ;
#
#
#
#
#             var marker_cf796c9c7565be9019410d5b32392ebb = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_bf911903f77e6a6a86aecbfeda70cfe9);
#
#
#         var popup_98582aa623f03df38ce13a7405bbfe49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f4b9fe9428412df441bf4c4aa12cc3c = $(`&lt;div id=&quot;html_1f4b9fe9428412df441bf4c4aa12cc3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_98582aa623f03df38ce13a7405bbfe49.setContent(html_1f4b9fe9428412df441bf4c4aa12cc3c);
#
#
#
#         marker_cf796c9c7565be9019410d5b32392ebb.bindPopup(popup_98582aa623f03df38ce13a7405bbfe49)
#         ;
#
#
#
#
#             var marker_5c399032352c553266bcbf7df08ab5bd = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_bf911903f77e6a6a86aecbfeda70cfe9);
#
#
#         var popup_aecfdfba3f645a17965e62ff5fd14f01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_836f6b926af9bd2ea2a087a7543b73dc = $(`&lt;div id=&quot;html_836f6b926af9bd2ea2a087a7543b73dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_aecfdfba3f645a17965e62ff5fd14f01.setContent(html_836f6b926af9bd2ea2a087a7543b73dc);
#
#
#
#         marker_5c399032352c553266bcbf7df08ab5bd.bindPopup(popup_aecfdfba3f645a17965e62ff5fd14f01)
#         ;
#
#
#
#
#             var marker_2cf72401cef5a1c34556db7ffe81c516 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_bf911903f77e6a6a86aecbfeda70cfe9);
#
#
#         var popup_8ac43677ca193b78dd5b91f8a661ce54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef518cc5255ec83b172205fc8e5dd0ea = $(`&lt;div id=&quot;html_ef518cc5255ec83b172205fc8e5dd0ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_8ac43677ca193b78dd5b91f8a661ce54.setContent(html_ef518cc5255ec83b172205fc8e5dd0ea);
#
#
#
#         marker_2cf72401cef5a1c34556db7ffe81c516.bindPopup(popup_8ac43677ca193b78dd5b91f8a661ce54)
#         ;
#
#
#
#
#             var marker_653c121457bc0e121b92174c2aabc5eb = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_bf911903f77e6a6a86aecbfeda70cfe9);
#
#
#         var popup_bcf4df05eeb916aa7516cf39159c10a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dbcfb286b3cc13483e52c586cad5301 = $(`&lt;div id=&quot;html_8dbcfb286b3cc13483e52c586cad5301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_bcf4df05eeb916aa7516cf39159c10a9.setContent(html_8dbcfb286b3cc13483e52c586cad5301);
#
#
#
#         marker_653c121457bc0e121b92174c2aabc5eb.bindPopup(popup_bcf4df05eeb916aa7516cf39159c10a9)
#         ;
#
#
#
#
#             var marker_adb845aaa9ab93e6f877cf0d628309a7 = L.marker(
#                 [40.5416128, -112.1479974],
#                 {
# }

# %%
# Method 2: Using .apply() to add markers with our function for all rows
# initialize an empty map
utah_map = utah_map_empty

# Now apply this function to each row in our filtered DataFrame
# For each row, we'll pass:
# 1. The row itself (handled automatically by .apply())
# 2. Our map object (we need to specify this explicitly)
# 3. The "axis" value for .apply() to indicate we want to process row by row
# .apply() allows you to apply a function to each row in the dataframe
utah_df_locations.apply(
    create_map_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0910a84cfa6f5f8f25922a81ee876a88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0910a84cfa6f5f8f25922a81ee876a88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0910a84cfa6f5f8f25922a81ee876a88 = L.map(
#                 &quot;map_0910a84cfa6f5f8f25922a81ee876a88&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cca5956d0814a6dce3cdc7eb6f466adc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cca5956d0814a6dce3cdc7eb6f466adc.addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
#
#             tile_layer_cca5956d0814a6dce3cdc7eb6f466adc.addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
#
#             var marker_f8c071380bb7db50cab83d6ab0d0145e = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
#
#         var popup_2476f5465e591c0cc53a4f8cb6435813 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e61a3183fb05078c446c5f65cc9ea5 = $(`&lt;div id=&quot;html_d0e61a3183fb05078c446c5f65cc9ea5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_2476f5465e591c0cc53a4f8cb6435813.setContent(html_d0e61a3183fb05078c446c5f65cc9ea5);
#
#
#
#         marker_f8c071380bb7db50cab83d6ab0d0145e.bindPopup(popup_2476f5465e591c0cc53a4f8cb6435813)
#         ;
#
#
#
#
#             var marker_4c352d3bee995051386dc9a8b4cd2d30 = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
#
#         var popup_c8bf4e91e253a5261beaa3477cf422bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c70cc933053d465ab2beb6bb44eeb4be = $(`&lt;div id=&quot;html_c70cc933053d465ab2beb6bb44eeb4be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_c8bf4e91e253a5261beaa3477cf422bc.setContent(html_c70cc933053d465ab2beb6bb44eeb4be);
#
#
#
#         marker_4c352d3bee995051386dc9a8b4cd2d30.bindPopup(popup_c8bf4e91e253a5261beaa3477cf422bc)
#         ;
#
#
#
#
#             var marker_1c5852ee5d500d88e029974bee7d6ac2 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
#
#         var popup_80a76b17cb24936d8861ed3d154f5789 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef001661967d12e0c4e59c294e54ea0d = $(`&lt;div id=&quot;html_ef001661967d12e0c4e59c294e54ea0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_80a76b17cb24936d8861ed3d154f5789.setContent(html_ef001661967d12e0c4e59c294e54ea0d);
#
#
#
#         marker_1c5852ee5d500d88e029974bee7d6ac2.bindPopup(popup_80a76b17cb24936d8861ed3d154f5789)
#         ;
#
#
#
#
#             var marker_72337b89d652cb071495ec2f63f4f322 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
#
#         var popup_9011875b144237ff20d6619f11cdc68c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5d5eb1ef4ee197d89a235ba0d4a5c4f = $(`&lt;div id=&quot;html_a5d5eb1ef4ee197d89a235ba0d4a5c4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_9011875b144237ff20d6619f11cdc68c.setContent(html_a5d5eb1ef4ee197d89a235ba0d4a5c4f);
#
#
#
#         marker_72337b89d652cb071495ec2f63f4f322.bindPopup(popup_9011875b144237ff20d6619f11cdc68c)
#         ;
#
#
#
#
#             var marker_693c4be51f27f5fee0e281e5ee3ba457 = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_0910a84cfa6f5f8f25922a81ee876a88);
#
#
#         var popup_411e2c2c4d2339e9f4c48cc07fb4f029 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e3c56b28cc63ebb80915903dc0f6ae2 = $(`&lt;div id=&quot;html_4e3c56b28cc63ebb80915903dc0f6ae2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_411e2c2c4d2339e9f4c48cc07fb4f029.setContent(html_4e3c56b28cc63ebb80915903dc0f6ae2);
#
#
#
#         marker_693c4be51f27f5fee0e281e5ee3ba457.bindPopup(popup_411e2c2c4d2339e9f4c48cc07fb4f029)
#         ;
#
#
#
#
#             var

# %% [markdown]
# Creating Circle Markers

# %%
# Melanie Walsh function we will edit:
#def create_ICE_map_markers(row, map_name):
#    folium.CircleMarker(location=[row['lat'], row['lon']], raidus=100, fill=True,
#                       popup=folium.Popup(f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}", max_width=200),
#                       tooltip=f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}"
#                       ).add_to(map_name)

def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=10,
                       fill=True,
                       popup=folium.Popup(f"{row['PO_Name'].title()}", max_width=200),
                       tooltip=f"{row['PO_Name'].title()}"
                       ).add_to(map_name)

# %%
# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(create_circle_markers, map_name=utah_map, axis="columns")

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7472e743fdf60852204c6a3ddefcc30c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7472e743fdf60852204c6a3ddefcc30c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7472e743fdf60852204c6a3ddefcc30c = L.map(
#                 &quot;map_7472e743fdf60852204c6a3ddefcc30c&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd002064b40e58b4940bacf8f644a7d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd002064b40e58b4940bacf8f644a7d9.addTo(map_7472e743fdf60852204c6a3ddefcc30c);
#
#
#             var circle_marker_7c479fee3263e97a69431180d45230c3 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7472e743fdf60852204c6a3ddefcc30c);
#
#
#         var popup_a45c3c8edb2ebdade5b6a91d6fc3f28b = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_688d06fb1f93b2604f554d24ce9657d8 = $(`&lt;div id=&quot;html_688d06fb1f93b2604f554d24ce9657d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_a45c3c8edb2ebdade5b6a91d6fc3f28b.setContent(html_688d06fb1f93b2604f554d24ce9657d8);
#
#
#
#         circle_marker_7c479fee3263e97a69431180d45230c3.bindPopup(popup_a45c3c8edb2ebdade5b6a91d6fc3f28b)
#         ;
#
#
#
#
#             circle_marker_7c479fee3263e97a69431180d45230c3.bindTooltip(
#                 `&lt;div&gt;
#                      Adamsville
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_8228a34fae7f6643fb97de6d037a0563 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7472e743fdf60852204c6a3ddefcc30c);
#
#
#         var popup_615b3adaf63220b1f33c48e968e638c7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_2529935902d5eaa53551587997bd559a = $(`&lt;div id=&quot;html_2529935902d5eaa53551587997bd559a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_615b3adaf63220b1f33c48e968e638c7.setContent(html_2529935902d5eaa53551587997bd559a);
#
#
#
#         circle_marker_8228a34fae7f6643fb97de6d037a0563.bindPopup(popup_615b3adaf63220b1f33c48e968e638c7)
#         ;
#
#
#
#
#             circle_marker_8228a34fae7f6643fb97de6d037a0563.bindTooltip(
#                 `&lt;div&gt;
#                      Alma
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_aeb17cf1a646d1fef256c4c8724d07a5 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7472e743fdf60852204c6a3ddefcc30c);
#
#
#         var popup_ec576d4af403eea2b051aab7e3e0cc45 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_49a9cffa9248cdfd3efff68625b0301c = $(`&lt;div id=&quot;html_49a9cffa9248cdfd3efff68625b0301c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_ec576d4af403eea2b051aab7e3e0cc45.setContent(html_49a9cffa9248cdfd3efff68625b0301c);

# %% [markdown]
# Customizing Marker Appearance

# %%
# alter map appearance
def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=14,
                       color='blue',
                       fill=True,
                       fill_color='white',
                       fill_opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c31ca1f616a275724730bc7f50f8ee55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c31ca1f616a275724730bc7f50f8ee55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c31ca1f616a275724730bc7f50f8ee55 = L.map(
#                 &quot;map_c31ca1f616a275724730bc7f50f8ee55&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd25917f2abdf277f176dc6289393903 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd25917f2abdf277f176dc6289393903.addTo(map_c31ca1f616a275724730bc7f50f8ee55);
#
#
#             var circle_marker_48a83714bf7d9a47d8e28eba0a9ce28c = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c31ca1f616a275724730bc7f50f8ee55);
#
#
#         var popup_4da32e9e21fa0e434f52510887169493 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_b03bf966e277513cbbe723b848bc58cb = $(`&lt;div id=&quot;html_b03bf966e277513cbbe723b848bc58cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_4da32e9e21fa0e434f52510887169493.setContent(html_b03bf966e277513cbbe723b848bc58cb);
#
#
#
#         circle_marker_48a83714bf7d9a47d8e28eba0a9ce28c.bindPopup(popup_4da32e9e21fa0e434f52510887169493)
#         ;
#
#
#
#
#             circle_marker_48a83714bf7d9a47d8e28eba0a9ce28c.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_3c16b6e8d4be0b180f484548b0c809f7 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c31ca1f616a275724730bc7f50f8ee55);
#
#
#         var popup_fa6598056e4438d606d3eb856e91635d = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_9ddad5dc617223a8594965a9b2286013 = $(`&lt;div id=&quot;html_9ddad5dc617223a8594965a9b2286013&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_fa6598056e4438d606d3eb856e91635d.setContent(html_9ddad5dc617223a8594965a9b2286013);
#
#
#
#         circle_marker_3c16b6e8d4be0b180f484548b0c809f7.bindPopup(popup_fa6598056e4438d606d3eb856e91635d)
#         ;
#
#
#
#
#             circle_marker_3c16b6e8d4be0b180f484548b0c809f7.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_fb4804db070c2fecced7bfc92c3468c7 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c31ca1f616a275724730bc7f50f8ee55);
#
#
#         var popup_dbdb49c3e2eece68fa06d99bdcdf56fa = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_745727f627f993dc43f9539aa3453e0f = $(`&lt;div id=&quot;html_745727f627f993dc43f9539aa3453e0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_dbdb49c3e2eece68fa06d99bdcdf56fa.setContent(html_74

# %% [markdown]
# Using a Function to Size the CirclesPermalink

# %%
# make new function to create circle markers sized by postmaster salary
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary'],
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcf12b8cde573a9df7ba349d0acc79b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcf12b8cde573a9df7ba349d0acc79b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcf12b8cde573a9df7ba349d0acc79b9 = L.map(
#                 &quot;map_dcf12b8cde573a9df7ba349d0acc79b9&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8de1e3bd52cd719f047990c9e27ddbc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8de1e3bd52cd719f047990c9e27ddbc3.addTo(map_dcf12b8cde573a9df7ba349d0acc79b9);
#
#
#             var circle_marker_5d08241736cf3c44fb5e5917d569d37b = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dcf12b8cde573a9df7ba349d0acc79b9);
#
#
#         var popup_92703d44e818589e463aab956a5b4db1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f1141a39f8b91842ab18f10647250e14 = $(`&lt;div id=&quot;html_f1141a39f8b91842ab18f10647250e14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_92703d44e818589e463aab956a5b4db1.setContent(html_f1141a39f8b91842ab18f10647250e14);
#
#
#
#         circle_marker_5d08241736cf3c44fb5e5917d569d37b.bindPopup(popup_92703d44e818589e463aab956a5b4db1)
#         ;
#
#
#
#
#             circle_marker_5d08241736cf3c44fb5e5917d569d37b.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_5032a878cad99214bc7bc00e0fae0fe3 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dcf12b8cde573a9df7ba349d0acc79b9);
#
#
#         var popup_e5ab95632419588397ee8958808a0424 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f146145b56ac7584eb17b0788de49442 = $(`&lt;div id=&quot;html_f146145b56ac7584eb17b0788de49442&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_e5ab95632419588397ee8958808a0424.setContent(html_f146145b56ac7584eb17b0788de49442);
#
#
#
#         circle_marker_5032a878cad99214bc7bc00e0fae0fe3.bindPopup(popup_e5ab95632419588397ee8958808a0424)
#         ;
#
#
#
#
#             circle_marker_5032a878cad99214bc7bc00e0fae0fe3.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_198311ab1d1b34e19e4c9af556785443 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dcf12b8cde573a9df7ba349d0acc79b9);
#
#
#         var popup_cc66584e1e214796ac8c44078e6c0f5a = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_08deccfc437c46ed790ca6fdb83c26ab = $(`&lt;div id=&quot;html_08deccfc437c46ed790ca6fdb83c26ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_cc66584e1e214796ac8c44078e6c0f5a.set

# %% [markdown]
# Adjusting Marker Sizes for Better VisibilityPermalink

# %%
# make new function to create circle markers sized by postmaster salary - this time adjusting the radius size in pixels to make it more legible
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary']/100,
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd68be84e57d14488a3d8e95c8975e56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd68be84e57d14488a3d8e95c8975e56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd68be84e57d14488a3d8e95c8975e56 = L.map(
#                 &quot;map_dd68be84e57d14488a3d8e95c8975e56&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f7c22b2da2c87243b5461864b9d5db8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f7c22b2da2c87243b5461864b9d5db8.addTo(map_dd68be84e57d14488a3d8e95c8975e56);
#
#
#             var circle_marker_d0fa9565237dfa8393b87011a5a14648 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd68be84e57d14488a3d8e95c8975e56);
#
#
#         var popup_41fdb24de79d3da87a90db6bc25b0aec = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_89fc0c77751dcf751e53955f5920af12 = $(`&lt;div id=&quot;html_89fc0c77751dcf751e53955f5920af12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_41fdb24de79d3da87a90db6bc25b0aec.setContent(html_89fc0c77751dcf751e53955f5920af12);
#
#
#
#         circle_marker_d0fa9565237dfa8393b87011a5a14648.bindPopup(popup_41fdb24de79d3da87a90db6bc25b0aec)
#         ;
#
#
#
#
#             circle_marker_d0fa9565237dfa8393b87011a5a14648.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a56f81e8e92adc16f26a219ba97cc814 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd68be84e57d14488a3d8e95c8975e56);
#
#
#         var popup_95625a98c7dbe7aa42370ab64a527c5e = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_c39b751cff440026e659d289fa5b65fd = $(`&lt;div id=&quot;html_c39b751cff440026e659d289fa5b65fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_95625a98c7dbe7aa42370ab64a527c5e.setContent(html_c39b751cff440026e659d289fa5b65fd);
#
#
#
#         circle_marker_a56f81e8e92adc16f26a219ba97cc814.bindPopup(popup_95625a98c7dbe7aa42370ab64a527c5e)
#         ;
#
#
#
#
#             circle_marker_a56f81e8e92adc16f26a219ba97cc814.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a8851e2677fff34b613a76b25f3a27e0 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd68be84e57d14488a3d8e95c8975e56);
#
#
#         var popup_5460697ee6953a8c60b5696b81efb826 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_bf48b6ca4dbf0f7a6092712867d5c42c = $(`&lt;div id=&quot;html_bf48b6ca4dbf0f7a6092712867d5c42c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_5460697ee6953a8c60b5696b81efb82

# %% [markdown]
# Categorizing Salaries Into Buckets

# %%
utah_df_locations.describe()
# Out:
#          PM_Salary    Latitude   Longitude
# count   132.000000  132.000000  132.000000
# mean    101.098485   39.907743 -112.161190
# std     344.225580    1.505091    0.593117
# min       4.000000   37.006375 -113.819415
# 25%      12.000000   38.874099 -112.379230
# 50%      22.000000   40.380926 -111.973830
# 75%      70.000000   41.080917 -111.819912
# max    3600.000000   42.187500 -111.281850

# %%
def add_salary_buckets(salary):
    # Create a new column for the salary bucket
    if salary < 50:
        bucket = 'Low Salary'
    elif salary >= 50 and salary < 250:
        bucket = 'Medium Salary'
    elif salary >= 250 and salary < 1000:
        bucket = 'High Salary'
    else:
        bucket = 'Very High Salary'
    return bucket

# %%
#test out the function
add_salary_buckets(2000)
# Out:
# 'Very High Salary'

# %%
utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
utah_df_locations.head()
# Out:
# C:\Users\rlove\AppData\Local\Temp\ipykernel_11268\2959544325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
#          PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0     Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1           Alma       Weber    UT         12  41.248833 -112.078275
# 2    Alpine City        Utah    UT         27  40.453283 -111.777986
# 3  American Fork        Utah    UT        130  40.375229 -111.796320
# 4       Bellevue  Washington    UT         20  37.340815 -113.274116
#
#    Salary_Bucket
# 0     Low Salary
# 1     Low Salary
# 2     Low Salary
# 3  Medium Salary
# 4     Low Salary

# %% [markdown]
# Creating Marker Sizes Based on Salary Categories

# %%
# create a function to add marker sizes based on the salary bucket
def add_marker_sizes(category):
    if category == 'Low Salary':
        return 4
    elif category == 'Medium Salary':
        return 8
    elif category == 'High Salary':
        return 12
    else:
        return 16

#test out the function
add_marker_sizes('High Salary')
# Out:
# 12

# %%
utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
utah_df_locations.head(10)
# Out:
# C:\Users\rlove\AppData\Local\Temp\ipykernel_11268\3689819186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
#            PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0       Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1             Alma       Weber    UT         12  41.248833 -112.078275
# 2      Alpine City        Utah    UT         27  40.453283 -111.777986
# 3    American Fork        Utah    UT        130  40.375229 -111.796320
# 4         Bellevue  Washington    UT         20  37.340815 -113.274116
# 5   Bingham Canyon   Salt Lake    UT         12  40.541613 -112.147997
# 7     Brigham City   Box Elder    UT        400  41.510213 -112.015501
# 8          Bullion       Piute    UT         12  38.410000 -112.339000
# 9       Cedar City        Iron    UT        200  37.676644 -113.057171
# 10    Cedar Valley        Utah    UT         13  40.327171 -112.104385
#
#     Salary_Bucket  Marker_Size
# 0      Low Salary            4
# 1      Low Salary            4
# 2      Low Salary            4
# 3   Medium Salary            8
# 4      Low Salary            4
# 5      Low Salary            4
# 7     High Salary           12
# 8      Low Salary            4
# 9   Medium Salary            8
# 10     Low Salary            4

# %% [markdown]
# Visualizing Postmaster Salaries by Categor

# %%
# make new function to create circle markers sized by salary category
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['Marker_Size'],
                       fill=True,
                       opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_359186fd0c24dde6e2a3e972f1c9549a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_359186fd0c24dde6e2a3e972f1c9549a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_359186fd0c24dde6e2a3e972f1c9549a = L.map(
#                 &quot;map_359186fd0c24dde6e2a3e972f1c9549a&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_428b0a6fa110ef33bd43a293e28f5dc8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_428b0a6fa110ef33bd43a293e28f5dc8.addTo(map_359186fd0c24dde6e2a3e972f1c9549a);
#
#
#             var circle_marker_5cb8bd682434aba1dfd00ff2a889a23b = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_359186fd0c24dde6e2a3e972f1c9549a);
#
#
#         var popup_6200aaf89a3a39eda8c134673951b5c0 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f41976fd1b5b3b0ea1cbfdb8bf6c6b9c = $(`&lt;div id=&quot;html_f41976fd1b5b3b0ea1cbfdb8bf6c6b9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_6200aaf89a3a39eda8c134673951b5c0.setContent(html_f41976fd1b5b3b0ea1cbfdb8bf6c6b9c);
#
#
#
#         circle_marker_5cb8bd682434aba1dfd00ff2a889a23b.bindPopup(popup_6200aaf89a3a39eda8c134673951b5c0)
#         ;
#
#
#
#
#             circle_marker_5cb8bd682434aba1dfd00ff2a889a23b.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_54e611c6012c95edde825bb7caaaab06 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_359186fd0c24dde6e2a3e972f1c9549a);
#
#
#         var popup_432c8d2a875e1de19fb12da45cdc1aab = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_dd2464cb96b470b0013efb7c6664b7b5 = $(`&lt;div id=&quot;html_dd2464cb96b470b0013efb7c6664b7b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_432c8d2a875e1de19fb12da45cdc1aab.setContent(html_dd2464cb96b470b0013efb7c6664b7b5);
#
#
#
#         circle_marker_54e611c6012c95edde825bb7caaaab06.bindPopup(popup_432c8d2a875e1de19fb12da45cdc1aab)
#         ;
#
#
#
#
#             circle_marker_54e611c6012c95edde825bb7caaaab06.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ce31f417e4cec74c595396c9d24d1554 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_359186fd0c24dde6e2a3e972f1c9549a);
#
#
#         var popup_f190fa01ddf3e4730e15079272257bad = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4cde9b8c798c5ef6424858f446e1ba46 = $(`&lt;div id=&quot;html_4cde9b8c798c5ef6424858f446e1ba46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_f190fa01ddf3e4730e15079272257bad.setCon

# %% [markdown]
# **New Dataset**

# %%
post_df = pd.read_csv('1877-official-register.csv')
print(post_df.sample(5))
post_df.dtypes
# Out:
#            Name State                  Department  \
# 476  Las Cruces    NM         Treasury Department
# 76        Boise    ID  Department of the Interior
# 465    Victoria    BC         Treasury Department
# 454      Yakima    WA                    Judicial
# 632        Waco    TX         Treasury Department
#
#                               Type  People   Latitude   Longitude
# 476                Customs Service       1  32.319940 -106.763654
# 76   General Land Office Registers       1  43.618710 -116.214607
# 465                Customs Service       1  48.428421 -123.365644
# 454                          Court       1  46.602071 -120.505899
# 632       Internal Revenue_Gaugers       1  31.549333  -97.146670
# Name           object
# State          object
# Department     object
# Type           object
# People          int64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
us_map_empty = folium.Map(location=[40, -97], zoom_start=4)
us_map_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57449d482568773d966acb2fbf37f69e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57449d482568773d966acb2fbf37f69e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57449d482568773d966acb2fbf37f69e = L.map(
#                 &quot;map_57449d482568773d966acb2fbf37f69e&quot;,
#                 {
#                     center: [40.0, -97.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9183072c45566b3035fcba7cb87665da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9183072c45566b3035fcba7cb87665da.addTo(map_57449d482568773d966acb2fbf37f69e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def create_empty_map():
    return folium.Map(location=[40, -97], zoom_start=4)

us_map = create_empty_map()
us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb742082e38ed06b4598274a603812a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb742082e38ed06b4598274a603812a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb742082e38ed06b4598274a603812a6 = L.map(
#                 &quot;map_fb742082e38ed06b4598274a603812a6&quot;,
#                 {
#                     center: [40.0, -97.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16bcb75215c3ebb45f34f338ce9fd4d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_16bcb75215c3ebb45f34f338ce9fd4d5.addTo(map_fb742082e38ed06b4598274a603812a6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Check for columns with missing values
missing_values = post_df.isna().sum()
print(missing_values)
# Out:
# Name          0
# State         0
# Department    0
# Type          0
# People        0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
# Filter out post offices that are missing a latitude value (ie. we don't have any location information about it)
post_df_locations = post_df[post_df['Latitude'].notna()]
print(len(post_df))
print(len(post_df_locations))
# Out:
# 903
# 903

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['PO_Name']).add_to(map_name)

# %%
# Method 1: Using a for loop to iterate through our dataframe and add markers sequentially
# initialize an empty map
post_map = create_empty_map()

# iterrows() allows you to loop through a dataframe row by row and return the index position + the row
for index, row in post_df_locations.iterrows():
    print(f"Name of post office:", row[0])

#now let's iterate through and call our function for each row
for index, row in post_df_locations.iterrows():
    create_map_markers(row, post_map)

post_map
# Out:
# C:\Users\rlove\AppData\Local\Temp\ipykernel_11268\466235520.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Name of post office:", row[0])
# Name of post office: Prescott
# Name of post office: Florence
# Name of post office: San Francisco
# Name of post office: Marysville
# Name of post office: Humboldt
# Name of post office: Stockton
# Name of post office: Visalia
# Name of post office: Sacramento
# Name of post office: Los Angeles
# Name of post office: Shasta
# Name of post office: Susanville
# Name of post office: Independence
# Name of post office: Denver
# Name of post office: Fair Play
# Name of post office: Central City
# Name of post office: Pueblo
# Name of post office: Del Norte
# Name of post office: Camp Gaston
# Name of post office: Presidio
# Name of post office: Fort Yuma
# Name of post office: Fort Lyon
# Name of post office: Fort Garland
# Name of post office: Fort Hall
# Name of post office: Fort Boise
# Name of post office: Fort Lapwai
# Name of post office: Lewiston
# Name of post office: Fort Leavenworth
# Name of post office: Fort Hays
# Name of post office: Fort Dodge
# Name of post office: Fort Larned
# Name of post office: Fort Riley
# Name of post office: Fort Wallace
# Name of post office: Fort Shaw
# Name of post office: Fort Ellis
# Name of post office: Fort Benton
# Name of post office: Camp Baker
# Name of post office: Big Horn Barracks
# Name of post office: Tongue River Barracks
# Name of post office: Missoula
# Name of post office: Fort Abercrombie
# Name of post office: Fort Totten
# Name of post office: Fort Buford
# Name of post office: Fort A Lincoln
# Name of post office: Fort Rice
# Name of post office: Fort Stevenson
# Name of post office: Fort Pembina
# Name of post office: Omaha Barracks
# Name of post office: North Platte
# Name of post office: Camp Robinson
# Name of post office: Camp Sheridan
# Name of post office: Sidney Barracks
# Name of post office: Fort McPherson
# Name of post office: Fort Hartsnuff
# Name of post office: Fort Marcy
# Name of post office: Fort Bayard
# Name of post office: Fort Craig
# Name of post office: Fort Stanton
# Name of post office: Fort Union
# Name of post office: Fort Wingate
# Name of post office: Camp McDermit
# Name of post office: Camp Halleck
# Name of post office: Fort Sill
# Name of post office: Fort Reno
# Name of post office: Camp Supply
# Name of post office: Fort Gibson
# Name of post office: HQ Dept of Columbia
# Name of post office: Camp Harney
# Name of post office: Fort Klamath
# Name of post office: Fort Stevens
# Name of post office: Fort Sisseton
# Name of post office: Fort Randall
# Name of post office: Fort Sully
# Name of post office: Fort Seward
# Name of post office: Cheyenne Agency
# Name of post office: Standing Rock Agency
# Name of post office: Lower Brule Agency
# Name of post office: Fort Elliot
# Name of post office: HQ Dept of Texas
# Name of post office: Fort Clark
# Name of post office: Fort Concho
# Name of post office: Fort Davis
# Name of post office: Fort Duncan
# Name of post office: Fort Griffin
# Name of post office: Fort McKavett
# Name of post office: Fort Richardson
# Name of post office: Fort Stockton
# Name of post office: Fort McIntosh
# Name of post office: Fort Brown
# Name of post office: Ringgold Barracks
# Name of post office: San Felipe
# Name of post office: Fort Cameron
# Name of post office: Camp Douglas
# Name of post office: Fort Canby
# Name of post office: Fort Colville
# Name of post office: Fort Townsend
# Name of post office: Fort Vancouver
# Name of post office: Fort Walla Walla
# Name of post office: Fort Laramie
# Name of post office: Fort DA Russell
# Name of post office: Fort Sanders
# Name of post office: Fort Fred Steele
# Name of post office: Fort McKinney
# Name of post office: Camp Stambaugh
# Name of post office: Fort Bridger
# Name of post office: Camp Brown
# Name of post office: Fort Fetterman
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PO_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 11
#       9 #now let's iterate through and call our function for each row
#      10 for index, row in post_df_locations.iterrows():
# ---> 11     create_map_markers(row, post_map)
#      13 post_map
#
# Cell In[75], line 6, in create_map_markers(row, map_name)
#       5 def create_map_markers(row, map_name):
# ----> 6     folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['PO_Name']).add_to(map_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'PO_Name'
