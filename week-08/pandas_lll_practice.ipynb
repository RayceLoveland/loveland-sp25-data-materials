# %%
import pandas as pd

# %%
utah_df = pd.read_csv('utah-census-1880.csv', delimiter=",")

# %%
utah_df
# Out:
#                              key   page  line  district  \
# 0             0212A_2_NEWBOLD_29  0212A     2      3072
# 1       0163A_45_CHRISTIANSEN_37  0163A    45      2560
# 2              0120A_1_JENSEN_71  0120A     1      2048
# 3              0120A_2_JENSEN_69  0120A     2      2048
# 4               0120A_3_ENGBER_6  0120A     3      2048
# ...                          ...    ...   ...       ...
# 142706              0543B_37__30  0543B    37     26624
# 142707              0543B_38__25  0543B    38     26624
# 142708     154A_50_HARRINGTON_77   154A    50     20992
# 142709         0064A_22_WIGHT_21  0064A    22      1024
# 142710          3B_24_LEES_0.417     3B    24     10241
#
#                                   location     county  household  family  \
# 0                               Smithfield      CACHE       9157     158
# 1                                    Hyrum      CACHE        150     151
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
utah_df.sample(12)
# Out:
#                            key   page  line  district  \
# 5198         0173B_6_PARKER_23  0173B     6      2560
# 19981      0028A_33_ROBERTS_21  0028A    33       512
# 128389      0378A_29_STEELE_34  0378A    29     24064
# 42814     0501C_41_RAPPLEYE_12  0501C    41      8448
# 3243         0152B_33_LARSON_2  0152B    33      2304
# 27685           0115A_5_MON_35  0115A     5      1792
# 54244        0032C_17_WHITE_10  0032C    17     10753
# 24698          0082B_12_MAN_50  0082B    12      1536
# 56830       0059B_38_BURTON_28  0059B    38     11009
# 88147       0053C_47_CHAPMAN_2  0053C    47     18945
# 102556  0412C_38_WESTINSKOW_41  0412C    38     16640
# 30874     0357A_20_ROBINSON_20  0357A    20      5377
#
#                               location      county  household  family  \
# 5198                        Wellsville       CACHE         10      11
# 19981             Minersville Precinct      BEAVER         49      49
# ...

# %%
utah_df=utah_df.rename(columns={"birthstate":"birthplace"})
utah_df
# Out:
#                              key   page  line  district  \
# 0             0212A_2_NEWBOLD_29  0212A     2      3072
# 1       0163A_45_CHRISTIANSEN_37  0163A    45      2560
# 2              0120A_1_JENSEN_71  0120A     1      2048
# 3              0120A_2_JENSEN_69  0120A     2      2048
# 4               0120A_3_ENGBER_6  0120A     3      2048
# ...                          ...    ...   ...       ...
# 142706              0543B_37__30  0543B    37     26624
# 142707              0543B_38__25  0543B    38     26624
# 142708     154A_50_HARRINGTON_77   154A    50     20992
# 142709         0064A_22_WIGHT_21  0064A    22      1024
# 142710          3B_24_LEES_0.417     3B    24     10241
#
#                                   location     county  household  family  \
# 0                               Smithfield      CACHE       9157     158
# 1                                    Hyrum      CACHE        150     151
# ...

# %%
def replace_married(some_string):
    if some_string=='m': 
        return "married"
    elif some_string=='s':
        return "single"
    elif some_string== 'w':
        return "widowed"
replace_married('s')
# Out:
# 'single'

# %%
utah_df['marrystatus'].apply(replace_married)
# Out:
# 0         married
# 1         married
# 2         married
# 3         married
# 4          single
#            ...
# 142706       None
# 142707       None
# 142708    widowed
# 142709     single
# 142710     single
# Name: marrystatus, Length: 142711, dtype: object

# %%
utah_df
# Out:
#                              key   page  line  district  \
# 0             0212A_2_NEWBOLD_29  0212A     2      3072
# 1       0163A_45_CHRISTIANSEN_37  0163A    45      2560
# 2              0120A_1_JENSEN_71  0120A     1      2048
# 3              0120A_2_JENSEN_69  0120A     2      2048
# 4               0120A_3_ENGBER_6  0120A     3      2048
# ...                          ...    ...   ...       ...
# 142706              0543B_37__30  0543B    37     26624
# 142707              0543B_38__25  0543B    38     26624
# 142708     154A_50_HARRINGTON_77   154A    50     20992
# 142709         0064A_22_WIGHT_21  0064A    22      1024
# 142710          3B_24_LEES_0.417     3B    24     10241
#
#                                   location     county  household  family  \
# 0                               Smithfield      CACHE       9157     158
# 1                                    Hyrum      CACHE        150     151
# ...

# %% [markdown]
# make a backup in case

# %%
utah_df_back=utah_df ...

# %% [markdown]
# or
